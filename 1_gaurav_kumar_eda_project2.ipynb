# %% [markdown]
# #  QUESTION 1 Load the dataset into pandas and provide a summary of columns in the loaded dataset without any modification.

# %%
import pandas as pd #importing panda library 
import numpy as np #importing numpy library 
import seaborn as sns # importing seaborn library 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/Gaurav/Desktop/data sheet/all_data_copy.csv") #reading the data set
"C:/Users/Gaurav/Desktop/data sheet/all_data_copy.csv"
df #data set
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 373695   259353    AAA Batteries (4-pack)                3       2.99
# 373696   259354                    iPhone                1        700
# 373697   259355                    iPhone                1        700
# 373698   259356    34in Ultrawide Monitor                1     379.99
# 373699   259357      USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# 0       01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1       01/28/19 14:15         185 Maple St, Portland, OR 97035
# 2       01/17/19 13:33    538 Adams St, San Francisco, CA 94016
# 3       01/05/19 20:33       738 10th St, Los Angeles, CA 90001
# 4       01/25/19 11:59            387 10th St, Austin, TX 73301
# ...                ...                                      ...
# 373695  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 373696  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 373697  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 373698  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 373699  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
# [373700 rows x 6 columns]

# %%
#So in this data set we have 6 coloums of sales of  electronics products.
#First Columns is of Order id and second column is of the product which is sold.
#Third columns tell the quantity of the product which is ordered .
#Fourth Column is of the price of the product.
#Fifth Column depicts about the order date and time.And Six Column is of the address of the purchaser.

# %%
df1=df.copy() #doing deep copy to keep a copy of orginial data set
df1
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 373695   259353    AAA Batteries (4-pack)                3       2.99
# 373696   259354                    iPhone                1        700
# 373697   259355                    iPhone                1        700
# 373698   259356    34in Ultrawide Monitor                1     379.99
# 373699   259357      USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# 0       01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1       01/28/19 14:15         185 Maple St, Portland, OR 97035
# 2       01/17/19 13:33    538 Adams St, San Francisco, CA 94016
# 3       01/05/19 20:33       738 10th St, Los Angeles, CA 90001
# 4       01/25/19 11:59            387 10th St, Austin, TX 73301
# ...                ...                                      ...
# 373695  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 373696  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 373697  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 373698  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 373699  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
# [373700 rows x 6 columns]

# %% [markdown]
# # Data Information

# %%
df.head(10) # Top 10 data of data set
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   141234                      iPhone                1        700
# 1   141235    Lightning Charging Cable                1      14.95
# 2   141236            Wired Headphones                2      11.99
# 3   141237            27in FHD Monitor                1     149.99
# 4   141238            Wired Headphones                1      11.99
# 5   141239      AAA Batteries (4-pack)                1       2.99
# 6   141240      27in 4K Gaming Monitor                1     389.99
# 7   141241        USB-C Charging Cable                1      11.95
# 8   141242  Bose SoundSport Headphones                1      99.99
# 9   141243    Apple Airpods Headphones                1        150
#
#        Order Date                         Purchase Address
# 0  01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15         185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33    538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33       738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59            387 10th St, Austin, TX 73301
# 5  01/29/19 20:22   775 Willow St, San Francisco, CA 94016
# 6  01/26/19 12:16       979 Park St, Los Angeles, CA 90001
# 7  01/05/19 12:04      181 6th St, San Francisco, CA 94016
# 8  01/01/19 10:30     867 Willow St, Los Angeles, CA 90001
# 9  01/22/19 21:20  657 Johnson St, San Francisco, CA 94016

# %%
df.tail(10) # Last 10 data of data set
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 373690   259349    AAA Batteries (4-pack)                1       2.99
# 373691   259350              Google Phone                1        600
# 373692   259350      USB-C Charging Cable                1      11.95
# 373693   259351  Apple Airpods Headphones                1        150
# 373694   259352      USB-C Charging Cable                1      11.95
# 373695   259353    AAA Batteries (4-pack)                3       2.99
# 373696   259354                    iPhone                1        700
# 373697   259355                    iPhone                1        700
# 373698   259356    34in Ultrawide Monitor                1     379.99
# 373699   259357      USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# 373690  09/01/19 22:14           911 River St, Dallas, TX 75001
# 373691  09/30/19 13:49    519 Maple St, San Francisco, CA 94016
# 373692  09/30/19 13:49    519 Maple St, San Francisco, CA 94016
# 373693  09/01/19 19:43      981 4th St, New York City, NY 10001
# 373694  09/07/19 15:49   976 Forest St, San Francisco, CA 94016
# 373695  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 373696  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 373697  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 373698  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 373699  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016

# %%
df.info() #to check the data type and null value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373700 entries, 0 to 373699
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          372610 non-null  object
#  1   Product           372610 non-null  object
#  2   Quantity Ordered  372610 non-null  object
#  3   Price Each        372610 non-null  object
#  4   Order Date        372610 non-null  object
#  5   Purchase Address  372610 non-null  object
# dtypes: object(6)
# memory usage: 17.1+ MB

# %% [markdown]
# # QUESTION 2 :-Prepare the data frame for further analysis. Clean it, mold it in any manner you see fit.

# %%
# Data Cleaning
#Since there may be a chance of dubplicate data and null value
#So we have to find and drop it for further analaysis

# %%
#since there are  373700 products and 372610 are non-null count products so there must be null product.Lets confirm in the next step.

# %%
df.isna().sum() #to check the total null value
# Out:
# Order ID            1090
# Product             1090
# Quantity Ordered    1090
# Price Each          1090
# Order Date          1090
# Purchase Address    1090
# dtype: int64

# %%
#null value present in the data set so we have to drop it

# %%
nan_df = df[df.isna().any(axis=1)] 
nan_df.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 664       NaN     NaN              NaN        NaN        NaN              NaN
# 678       NaN     NaN              NaN        NaN        NaN              NaN
# 797       NaN     NaN              NaN        NaN        NaN              NaN
# 876       NaN     NaN              NaN        NaN        NaN              NaN
# 1299      NaN     NaN              NaN        NaN        NaN              NaN

# %%
df.dropna(how='all',inplace=True) #dropping nan value
df.isna().sum()              #checking if any nan value left
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
#there is no Null values now.

# %%
df.info() #information of the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372610 entries, 0 to 373699
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          372610 non-null  object
#  1   Product           372610 non-null  object
#  2   Quantity Ordered  372610 non-null  object
#  3   Price Each        372610 non-null  object
#  4   Order Date        372610 non-null  object
#  5   Purchase Address  372610 non-null  object
# dtypes: object(6)
# memory usage: 19.9+ MB

# %%
#there are 372610 enteries and all are non-null count so its confirmed that there are no null data present

# %%
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
#sorting by order Id

# %%
df.sort_values(by=['Order ID'], inplace=True)  #sorting

# %%
df.tail(10)
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 169437  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 289538  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 169514  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 289304  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 289275  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 169827  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 288934  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 287409  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 178745  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 246431  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address
# 169437  Purchase Address
# 289538  Purchase Address
# 169514  Purchase Address
# 289304  Purchase Address
# 289275  Purchase Address
# 169827  Purchase Address
# 288934  Purchase Address
# 287409  Purchase Address
# 178745  Purchase Address
# 246431  Purchase Address

# %%
df.duplicated().value_counts() #checking dublicate value
# Out:
# True     186923
# False    185687
# dtype: int64

# %%
dfa=df.drop_duplicates(subset=None, keep='first', inplace=False)
dfa
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone                 1         700
# 254398    141235    Lightning Charging Cable                 1       14.95
# 2         141236            Wired Headphones                 2       11.99
# 3         141237            27in FHD Monitor                 1      149.99
# 4         141238            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 186846    319667       AA Batteries (4-pack)                 2        3.84
# 242358    319668             Vareebadd Phone                 1         400
# 242359    319669            Wired Headphones                 1       11.99
# 186849    319670  Bose SoundSport Headphones                 1       99.99
# 124526  Order ID                     Product  Quantity Ordered  Price Each
#
#             Order Date                        Purchase Address
# 0       01/22/19 21:25         944 Walnut St, Boston, MA 02215
# 254398  01/28/19 14:15        185 Maple St, Portland, OR 97035
# 2       01/17/19 13:33   538 Adams St, San Francisco, CA 94016
# 3       01/05/19 20:33      738 10th St, Los Angeles, CA 90001
# 4       01/25/19 11:59           387 10th St, Austin, TX 73301
# ...                ...                                     ...
# 186846  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001
# 242358  12/09/19 06:43        273 Wilson St, Seattle, WA 98101
# 242359  12/03/19 10:39          778 River St, Dallas, TX 75001
# 186849  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001
# 124526      Order Date                        Purchase Address
#
# [185687 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372610 entries, 0 to 246431
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          372610 non-null  object
#  1   Product           372610 non-null  object
#  2   Quantity Ordered  372610 non-null  object
#  3   Price Each        372610 non-null  object
#  4   Order Date        372610 non-null  object
#  5   Purchase Address  372610 non-null  object
# dtypes: object(6)
# memory usage: 19.9+ MB

# %%
#there are 372610 enteries and all are non-null count so its confirmed that there are no null data present

# %%
df.head()
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 254397   141234                    iPhone                1        700
# 254398   141235  Lightning Charging Cable                1      14.95
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
#
#             Order Date                       Purchase Address
# 0       01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 254397  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 254398  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 1       01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2       01/17/19 13:33  538 Adams St, San Francisco, CA 94016

# %%
df.columns = ['Order_ID', 'Product', 'Quantity_Ordered', 'Price_Each', 'Order_Date', 'Purchase_Address']
df.head()
# Out:
#        Order_ID                   Product Quantity_Ordered Price_Each  \
# 0        141234                    iPhone                1        700
# 254397   141234                    iPhone                1        700
# 254398   141235  Lightning Charging Cable                1      14.95
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
#
#             Order_Date                       Purchase_Address
# 0       01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 254397  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 254398  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 1       01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2       01/17/19 13:33  538 Adams St, San Francisco, CA 94016

# %%
df['Date'] = df['Order_Date'].str[:8]
df
# Out:
#         Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0         141234                    iPhone                 1         700
# 254397    141234                    iPhone                 1         700
# 254398    141235  Lightning Charging Cable                 1       14.95
# 1         141235  Lightning Charging Cable                 1       14.95
# 2         141236          Wired Headphones                 2       11.99
# ...          ...                       ...               ...         ...
# 169827  Order ID                   Product  Quantity Ordered  Price Each
# 288934  Order ID                   Product  Quantity Ordered  Price Each
# 287409  Order ID                   Product  Quantity Ordered  Price Each
# 178745  Order ID                   Product  Quantity Ordered  Price Each
# 246431  Order ID                   Product  Quantity Ordered  Price Each
#
#             Order_Date                       Purchase_Address      Date
# 0       01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19
# 254397  01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19
# 254398  01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19
# 1       01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19
# 2       01/17/19 13:33  538 Adams St, San Francisco, CA 94016  01/17/19
# ...                ...                                    ...       ...
# 169827      Order Date                       Purchase Address  Order Da
# 288934      Order Date                       Purchase Address  Order Da
# 287409      Order Date                       Purchase Address  Order Da
# 178745      Order Date                       Purchase Address  Order Da
# 246431      Order Date                       Purchase Address  Order Da
#
# [372610 rows x 7 columns]

# %%
df['Month'] = df['Order_Date'].str[:2] #making a spearate column for month
df
# Out:
#         Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0         141234                    iPhone                 1         700
# 254397    141234                    iPhone                 1         700
# 254398    141235  Lightning Charging Cable                 1       14.95
# 1         141235  Lightning Charging Cable                 1       14.95
# 2         141236          Wired Headphones                 2       11.99
# ...          ...                       ...               ...         ...
# 169827  Order ID                   Product  Quantity Ordered  Price Each
# 288934  Order ID                   Product  Quantity Ordered  Price Each
# 287409  Order ID                   Product  Quantity Ordered  Price Each
# 178745  Order ID                   Product  Quantity Ordered  Price Each
# 246431  Order ID                   Product  Quantity Ordered  Price Each
#
#             Order_Date                       Purchase_Address      Date Month
# 0       01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19    01
# 254397  01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19    01
# 254398  01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19    01
# 1       01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19    01
# 2       01/17/19 13:33  538 Adams St, San Francisco, CA 94016  01/17/19    01
# ...                ...                                    ...       ...   ...
# 169827      Order Date                       Purchase Address  Order Da    Or
# 288934      Order Date                       Purchase Address  Order Da    Or
# 287409      Order Date                       Purchase Address  Order Da    Or
# 178745      Order Date                       Purchase Address  Order Da    Or
# 246431      Order Date                       Purchase Address  Order Da    Or
#
# [372610 rows x 8 columns]

# %%
df['Month'] = df['Order_Date'].str[:2] #making a spearate column for month
df
# Out:
#         Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0         141234                    iPhone                 1         700
# 254397    141234                    iPhone                 1         700
# 254398    141235  Lightning Charging Cable                 1       14.95
# 1         141235  Lightning Charging Cable                 1       14.95
# 2         141236          Wired Headphones                 2       11.99
# ...          ...                       ...               ...         ...
# 169827  Order ID                   Product  Quantity Ordered  Price Each
# 288934  Order ID                   Product  Quantity Ordered  Price Each
# 287409  Order ID                   Product  Quantity Ordered  Price Each
# 178745  Order ID                   Product  Quantity Ordered  Price Each
# 246431  Order ID                   Product  Quantity Ordered  Price Each
#
#             Order_Date                       Purchase_Address      Date Month
# 0       01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19    01
# 254397  01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19    01
# 254398  01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19    01
# 1       01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19    01
# 2       01/17/19 13:33  538 Adams St, San Francisco, CA 94016  01/17/19    01
# ...                ...                                    ...       ...   ...
# 169827      Order Date                       Purchase Address  Order Da    Or
# 288934      Order Date                       Purchase Address  Order Da    Or
# 287409      Order Date                       Purchase Address  Order Da    Or
# 178745      Order Date                       Purchase Address  Order Da    Or
# 246431      Order Date                       Purchase Address  Order Da    Or
#
# [372610 rows x 8 columns]

# %%
df[['House_No.','City','Pin_Code']] = df.Purchase_Address.str.split(",",expand=True)
df
# Out:
#         Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0         141234                    iPhone                 1         700
# 254397    141234                    iPhone                 1         700
# 254398    141235  Lightning Charging Cable                 1       14.95
# 1         141235  Lightning Charging Cable                 1       14.95
# 2         141236          Wired Headphones                 2       11.99
# ...          ...                       ...               ...         ...
# 169827  Order ID                   Product  Quantity Ordered  Price Each
# 288934  Order ID                   Product  Quantity Ordered  Price Each
# 287409  Order ID                   Product  Quantity Ordered  Price Each
# 178745  Order ID                   Product  Quantity Ordered  Price Each
# 246431  Order ID                   Product  Quantity Ordered  Price Each
#
#             Order_Date                       Purchase_Address      Date Month  \
# 0       01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19    01
# 254397  01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19    01
# 254398  01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19    01
# 1       01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19    01
# 2       01/17/19 13:33  538 Adams St, San Francisco, CA 94016  01/17/19    01
# ...                ...                                    ...       ...   ...
# 169827      Order Date                       Purchase Address  Order Da    Or
# 288934      Order Date                       Purchase Address  Order Da    Or
# 287409      Order Date                       Purchase Address  Order Da    Or
# 178745      Order Date                       Purchase Address  Order Da    Or
# 246431      Order Date                       Purchase Address  Order Da    Or
#
#                House_No.            City   Pin_Code
# 0          944 Walnut St          Boston   MA 02215
# 254397     944 Walnut St          Boston   MA 02215
# 254398      185 Maple St        Portland   OR 97035
# 1           185 Maple St        Portland   OR 97035
# 2           538 Adams St   San Francisco   CA 94016
# ...                  ...             ...        ...
# 169827  Purchase Address            None       None
# 288934  Purchase Address            None       None
# 287409  Purchase Address            None       None
# 178745  Purchase Address            None       None
# 246431  Purchase Address            None       None
#
# [372610 rows x 11 columns]

# %%
df2=df.copy() #again making a deep copy of changed data set for safety purposes
df2
# Out:
#         Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0         141234                    iPhone                 1         700
# 254397    141234                    iPhone                 1         700
# 254398    141235  Lightning Charging Cable                 1       14.95
# 1         141235  Lightning Charging Cable                 1       14.95
# 2         141236          Wired Headphones                 2       11.99
# ...          ...                       ...               ...         ...
# 169827  Order ID                   Product  Quantity Ordered  Price Each
# 288934  Order ID                   Product  Quantity Ordered  Price Each
# 287409  Order ID                   Product  Quantity Ordered  Price Each
# 178745  Order ID                   Product  Quantity Ordered  Price Each
# 246431  Order ID                   Product  Quantity Ordered  Price Each
#
#             Order_Date                       Purchase_Address      Date Month  \
# 0       01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19    01
# 254397  01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19    01
# 254398  01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19    01
# 1       01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19    01
# 2       01/17/19 13:33  538 Adams St, San Francisco, CA 94016  01/17/19    01
# ...                ...                                    ...       ...   ...
# 169827      Order Date                       Purchase Address  Order Da    Or
# 288934      Order Date                       Purchase Address  Order Da    Or
# 287409      Order Date                       Purchase Address  Order Da    Or
# 178745      Order Date                       Purchase Address  Order Da    Or
# 246431      Order Date                       Purchase Address  Order Da    Or
#
#                House_No.            City   Pin_Code
# 0          944 Walnut St          Boston   MA 02215
# 254397     944 Walnut St          Boston   MA 02215
# 254398      185 Maple St        Portland   OR 97035
# 1           185 Maple St        Portland   OR 97035
# 2           538 Adams St   San Francisco   CA 94016
# ...                  ...             ...        ...
# 169827  Purchase Address            None       None
# 288934  Purchase Address            None       None
# 287409  Purchase Address            None       None
# 178745  Purchase Address            None       None
# 246431  Purchase Address            None       None
#
# [372610 rows x 11 columns]

# %%
df.Month.value_counts() #to check the unique values
# Out:
# 12    49968
# 10    40564
# 04    36558
# 11    35146
# 05    33132
# 03    30306
# 07    28586
# 06    27108
# 02    23950
# 08    23922
# 09    23242
# 01    19418
# Or      710
# Name: Month, dtype: int64

# %%
#Here we can see that "Or" value which is not a month so we are going to remove those rows which has Or values in Month Column

# %%
temp_data = df[df['Month'].str[:2] == 'Or']
temp_data
# Out:
#         Order_ID  Product  Quantity_Ordered  Price_Each  Order_Date  \
# 124526  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 123581  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 123475  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 123406  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 122394  Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 169827  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 288934  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 287409  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 178745  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 246431  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase_Address      Date Month         House_No.  City Pin_Code
# 124526  Purchase Address  Order Da    Or  Purchase Address  None     None
# 123581  Purchase Address  Order Da    Or  Purchase Address  None     None
# 123475  Purchase Address  Order Da    Or  Purchase Address  None     None
# 123406  Purchase Address  Order Da    Or  Purchase Address  None     None
# 122394  Purchase Address  Order Da    Or  Purchase Address  None     None
# ...                  ...       ...   ...               ...   ...      ...
# 169827  Purchase Address  Order Da    Or  Purchase Address  None     None
# 288934  Purchase Address  Order Da    Or  Purchase Address  None     None
# 287409  Purchase Address  Order Da    Or  Purchase Address  None     None
# 178745  Purchase Address  Order Da    Or  Purchase Address  None     None
# 246431  Purchase Address  Order Da    Or  Purchase Address  None     None
#
# [710 rows x 11 columns]

# %%
df = df[df['Month'].str[:2] != 'Or']
df.head()
# Out:
#        Order_ID                   Product Quantity_Ordered Price_Each  \
# 0        141234                    iPhone                1        700
# 254397   141234                    iPhone                1        700
# 254398   141235  Lightning Charging Cable                1      14.95
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
#
#             Order_Date                       Purchase_Address      Date Month  \
# 0       01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19    01
# 254397  01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19    01
# 254398  01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19    01
# 1       01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19    01
# 2       01/17/19 13:33  538 Adams St, San Francisco, CA 94016  01/17/19    01
#
#             House_No.            City   Pin_Code
# 0       944 Walnut St          Boston   MA 02215
# 254397  944 Walnut St          Boston   MA 02215
# 254398   185 Maple St        Portland   OR 97035
# 1        185 Maple St        Portland   OR 97035
# 2        538 Adams St   San Francisco   CA 94016

# %%
df.shape
# Out:
# (371900, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371900 entries, 0 to 242360
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          371900 non-null  object
#  1   Product           371900 non-null  object
#  2   Quantity_Ordered  371900 non-null  object
#  3   Price_Each        371900 non-null  object
#  4   Order_Date        371900 non-null  object
#  5   Purchase_Address  371900 non-null  object
#  6   Date              371900 non-null  object
#  7   Month             371900 non-null  object
#  8   House_No.         371900 non-null  object
#  9   City              371900 non-null  object
#  10  Pin_Code          371900 non-null  object
# dtypes: object(11)
# memory usage: 34.0+ MB

# %%
df['Month'] = df['Month'].astype('int32')
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <ipython-input-37-d6563dc9eb24>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month'] = df['Month'].astype('int32')
# <ipython-input-37-d6563dc9eb24>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Order_Date'] = pd.to_datetime(df['Order_Date'])
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371900 entries, 0 to 242360
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          371900 non-null  object
#  1   Product           371900 non-null  object
#  2   Quantity_Ordered  371900 non-null  object
#  3   Price_Each        371900 non-null  object
#  4   Order_Date        371900 non-null  datetime64[ns]
#  5   Purchase_Address  371900 non-null  object
#  6   Date              371900 non-null  datetime64[ns]
#  7   Month             371900 non-null  int32
#  8   House_No.         371900 non-null  object
#  9   City              371900 non-null  object
#  10  Pin_Code          371900 non-null  object
# dtypes: datetime64[ns](2), int32(1), object(8)
# memory usage: 32.6+ MB
# <ipython-input-37-d6563dc9eb24>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df.Order_ID.value_counts()
# Out:
# 160873    10
# 289117     8
# 193511     8
# 242936     8
# 235798     8
#           ..
# 164745     2
# 195208     2
# 309606     2
# 247317     2
# 144500     2
# Name: Order_ID, Length: 178437, dtype: int64

# %%
df3=df.copy() #saving data set
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371900 entries, 0 to 242360
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          371900 non-null  object
#  1   Product           371900 non-null  object
#  2   Quantity_Ordered  371900 non-null  object
#  3   Price_Each        371900 non-null  object
#  4   Order_Date        371900 non-null  datetime64[ns]
#  5   Purchase_Address  371900 non-null  object
#  6   Date              371900 non-null  datetime64[ns]
#  7   Month             371900 non-null  int32
#  8   House_No.         371900 non-null  object
#  9   City              371900 non-null  object
#  10  Pin_Code          371900 non-null  object
# dtypes: datetime64[ns](2), int32(1), object(8)
# memory usage: 32.6+ MB

# %%
#orders are repeating so we cannot keep order id as index number

# %%
df.Quantity_Ordered.value_counts()
# Out:
# 1    337104
# 2     26648
# 3      5840
# 4      1612
# 5       472
# 6       160
# 7        48
# 8        10
# 9         6
# Name: Quantity_Ordered, dtype: int64

# %%
#All the values in Quantity Ordered column are Integer so have to convert it into Integer and Price Column to float.

# %%
df['Quantity_Ordered'] = df['Quantity_Ordered'].astype('int32')
df['Price_Each'] = df['Price_Each'].astype('float64')
df.info()
# Out:
# <ipython-input-43-23c73bcdf341>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Quantity_Ordered'] = df['Quantity_Ordered'].astype('int32')
# <ipython-input-43-23c73bcdf341>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price_Each'] = df['Price_Each'].astype('float64')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371900 entries, 0 to 242360
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          371900 non-null  object
#  1   Product           371900 non-null  object
#  2   Quantity_Ordered  371900 non-null  int32
#  3   Price_Each        371900 non-null  float64
#  4   Order_Date        371900 non-null  datetime64[ns]
#  5   Purchase_Address  371900 non-null  object
#  6   Date              371900 non-null  datetime64[ns]
#  7   Month             371900 non-null  int32
#  8   House_No.         371900 non-null  object
#  9   City              371900 non-null  object
#  10  Pin_Code          371900 non-null  object
# dtypes: datetime64[ns](2), float64(1), int32(2), object(6)
# memory usage: 31.2+ MB

# %%
df.describe()
# Out:
#        Quantity_Ordered     Price_Each          Month
# count     371900.000000  371900.000000  371900.000000
# mean           1.124383     184.399735       7.059140
# std            0.442792     332.730883       3.502991
# min            1.000000       2.990000       1.000000
# 25%            1.000000      11.950000       4.000000
# 50%            1.000000      14.950000       7.000000
# 75%            1.000000     150.000000      10.000000
# max            9.000000    1700.000000      12.000000

# %%
#so here we can see the maximum sells is 9 and minimum sell is 1 and 
#maximum price is 1700 and minimum price is 2.99
# month where maximum sell occured is december and least sell occur is month 1

# %%
#now lets make the Sales column

# %%
df['Sales'] = df['Quantity_Ordered'] * df['Price_Each']
df
# Out:
# <ipython-input-47-861272b05dc0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sales'] = df['Quantity_Ordered'] * df['Price_Each']
#        Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0        141234                      iPhone                 1      700.00
# 254397   141234                      iPhone                 1      700.00
# 254398   141235    Lightning Charging Cable                 1       14.95
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# ...         ...                         ...               ...         ...
# 186847   319668             Vareebadd Phone                 1      400.00
# 242359   319669            Wired Headphones                 1       11.99
# 186848   319669            Wired Headphones                 1       11.99
# 186849   319670  Bose SoundSport Headphones                 1       99.99
# 242360   319670  Bose SoundSport Headphones                 1       99.99
#
#                 Order_Date                        Purchase_Address       Date  \
# 0      2019-01-22 21:25:00         944 Walnut St, Boston, MA 02215 2019-01-22
# 254397 2019-01-22 21:25:00         944 Walnut St, Boston, MA 02215 2019-01-22
# 254398 2019-01-28 14:15:00        185 Maple St, Portland, OR 97035 2019-01-28
# 1      2019-01-28 14:15:00        185 Maple St, Portland, OR 97035 2019-01-28
# 2      2019-01-17 13:33:00   538 Adams St, San Francisco, CA 94016 2019-01-17
# ...                    ...                                     ...        ...
# 186847 2019-12-09 06:43:00        273 Wilson St, Seattle, WA 98101 2019-12-09
# 242359 2019-12-03 10:39:00          778 River St, Dallas, TX 75001 2019-12-03
# 186848 2019-12-03 10:39:00          778 River St, Dallas, TX 75001 2019-12-03
# 186849 2019-12-21 21:45:00  747 Chestnut St, Los Angeles, CA 90001 2019-12-21
# 242360 2019-12-21 21:45:00  747 Chestnut St, Los Angeles, CA 90001 2019-12-21
#
#         Month        House_No.            City   Pin_Code   Sales
# 0           1    944 Walnut St          Boston   MA 02215  700.00
# 254397      1    944 Walnut St          Boston   MA 02215  700.00
# 254398      1     185 Maple St        Portland   OR 97035   14.95
# 1           1     185 Maple St        Portland   OR 97035   14.95
# 2           1     538 Adams St   San Francisco   CA 94016   23.98
# ...       ...              ...             ...        ...     ...
# 186847     12    273 Wilson St         Seattle   WA 98101  400.00
# 242359     12     778 River St          Dallas   TX 75001   11.99
# 186848     12     778 River St          Dallas   TX 75001   11.99
# 186849     12  747 Chestnut St     Los Angeles   CA 90001   99.99
# 242360     12  747 Chestnut St     Los Angeles   CA 90001   99.99
#
# [371900 rows x 12 columns]

# %% [markdown]
# # Summary

# %%
# 1  In new data set we have separate coloumn for Time,date,Month,House_No., City, Pin_code
# 2  In new data set we can see the Sales Coloumn where it tells the price of total shopping
# 3  In data set all null values are eliminated
# 4  In data set order_id is repeating so we cannot keep it as index number
# 5  In old data set we had some null values,or in months all are cleaned in new data set.
# 5 Duplicate Data is removed from old data set

# %% [markdown]
# # Question 4: What is the distribution of sales among different cities in different months?

# %%
df4=df.copy() #keeping a copy for safety purpose
df4
# Out:
#        Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0        141234                      iPhone                 1      700.00
# 254397   141234                      iPhone                 1      700.00
# 254398   141235    Lightning Charging Cable                 1       14.95
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# ...         ...                         ...               ...         ...
# 186847   319668             Vareebadd Phone                 1      400.00
# 242359   319669            Wired Headphones                 1       11.99
# 186848   319669            Wired Headphones                 1       11.99
# 186849   319670  Bose SoundSport Headphones                 1       99.99
# 242360   319670  Bose SoundSport Headphones                 1       99.99
#
#                 Order_Date                        Purchase_Address       Date  \
# 0      2019-01-22 21:25:00         944 Walnut St, Boston, MA 02215 2019-01-22
# 254397 2019-01-22 21:25:00         944 Walnut St, Boston, MA 02215 2019-01-22
# 254398 2019-01-28 14:15:00        185 Maple St, Portland, OR 97035 2019-01-28
# 1      2019-01-28 14:15:00        185 Maple St, Portland, OR 97035 2019-01-28
# 2      2019-01-17 13:33:00   538 Adams St, San Francisco, CA 94016 2019-01-17
# ...                    ...                                     ...        ...
# 186847 2019-12-09 06:43:00        273 Wilson St, Seattle, WA 98101 2019-12-09
# 242359 2019-12-03 10:39:00          778 River St, Dallas, TX 75001 2019-12-03
# 186848 2019-12-03 10:39:00          778 River St, Dallas, TX 75001 2019-12-03
# 186849 2019-12-21 21:45:00  747 Chestnut St, Los Angeles, CA 90001 2019-12-21
# 242360 2019-12-21 21:45:00  747 Chestnut St, Los Angeles, CA 90001 2019-12-21
#
#         Month        House_No.            City   Pin_Code   Sales
# 0           1    944 Walnut St          Boston   MA 02215  700.00
# 254397      1    944 Walnut St          Boston   MA 02215  700.00
# 254398      1     185 Maple St        Portland   OR 97035   14.95
# 1           1     185 Maple St        Portland   OR 97035   14.95
# 2           1     538 Adams St   San Francisco   CA 94016   23.98
# ...       ...              ...             ...        ...     ...
# 186847     12    273 Wilson St         Seattle   WA 98101  400.00
# 242359     12     778 River St          Dallas   TX 75001   11.99
# 186848     12     778 River St          Dallas   TX 75001   11.99
# 186849     12  747 Chestnut St     Los Angeles   CA 90001   99.99
# 242360     12  747 Chestnut St     Los Angeles   CA 90001   99.99
#
# [371900 rows x 12 columns]

# %%
sale_data=df.groupby('Month').sum()
sale_data
# Out:
#        Quantity_Ordered    Price_Each         Sales
# Month
# 1                 21806  3.623537e+06  3.644513e+06
# 2                 26898  4.377769e+06  4.404045e+06
# 3                 34010  5.582416e+06  5.614201e+06
# 4                 41116  6.735342e+06  6.781340e+06
# 5                 37334  6.270250e+06  6.305214e+06
# 6                 30506  5.124051e+06  5.155605e+06
# 7                 32144  5.265079e+06  5.295552e+06
# 8                 26896  4.460691e+06  4.488936e+06
# 9                 26218  4.169984e+06  4.195120e+06
# 10                45406  7.431110e+06  7.473454e+06
# 11                39596  6.361201e+06  6.399206e+06
# 12                56228  9.176831e+06  9.226887e+06

# %%
# As we can December has maximum number of sales in terms of quantity ordered as well as sales value.
#After December we have November which is giving more number of sales
#Now lets plot and see the result in Graph

# %%
months = range(1, 13)
plt.bar(months, sale_data['Sales'])
plt.title('Sales per Month')
plt.xticks(months)
plt.xlabel('Months')
plt.ylabel('Sales')
plt.show()

# %%
#We can celarly see that December is giving maximum number of sales

# %% [markdown]
# # Which city had the highest sales overall?

# %%
city_sales=df.City.value_counts()
city_sales
# Out:
#  San Francisco    89464
#  Los Angeles      59210
#  New York City    49752
#  Boston           39868
#  Atlanta          29762
#  Dallas           29640
#  Seattle          29464
#  Portland         24930
#  Austin           19810
# Name: City, dtype: int64

# %%
#From the value we can predict clearly that San Francisco giving maximum sale then Los Angeles
#lets plot the graph for clear view

# %%
plt.figure(figsize=(16, 6))
sns.countplot(df['City'])
plt.xlabel("City Name")
plt.ylabel("Number of Sells")
plt.title("city vs Sales")
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'city vs Sales')

# %%
#As we can see that San Fransisco has the highest sales followed by Los Angels.
#Austin City has lowest sales
#Seattle and Dallas has almost equal number of sales

# %% [markdown]
# # Question 4.c Most bought products per city?.

# %%
result2=df.groupby('City').sum()
result2
# Out:
#                 Quantity_Ordered    Price_Each   Month         Sales     Hour
# City
#  Atlanta                   33204  5.559816e+06  209588  5.590997e+06   428528
#  Austin                    22306  3.619747e+06  139658  3.639164e+06   283892
#  Boston                    45056  7.274820e+06  282224  7.323284e+06   576450
#  Dallas                    33460  5.505256e+06  209240  5.535951e+06   428780
#  Los Angeles               66578  1.084287e+07  416650  1.090514e+07   854888
#  New York City             55864  9.270742e+06  351482  9.328635e+06   715392
#  Portland                  28106  4.615495e+06  175530  4.640981e+06   359264
#  San Francisco            100478  1.642292e+07  631040  1.652441e+07  1286530
#  Seattle                   33106  5.466592e+06  209882  5.495511e+06   426584

# %%
cities=df['City'].unique()
plt.bar(cities,result2['Sales'])
plt.xticks(cities, rotation='vertical',size =8)
label,location = plt.yticks()
plt.yticks(label, (label/1000000).astype(int))
plt.ylabel('Sales in Million USD')
plt.xlabel('City Name')
plt.show()

# %%
#As we can see that new york city has highest number of sells followed by Austin.

# %% [markdown]
# # Q5 Find out the distribution of sales over different times of the day (Morning, Afternoon, Evening, Night) and answer the following for each city;d

# %%
df['Hour'] = df.Order_Date.dt.hour
df.head()
# Out:
# <ipython-input-58-8eea1e87f8c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hour'] = df.Order_Date.dt.hour
#        Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0        141234                    iPhone                 1      700.00
# 254397   141234                    iPhone                 1      700.00
# 254398   141235  Lightning Charging Cable                 1       14.95
# 1        141235  Lightning Charging Cable                 1       14.95
# 2        141236          Wired Headphones                 2       11.99
#
#                 Order_Date                       Purchase_Address       Date  \
# 0      2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215 2019-01-22
# 254397 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215 2019-01-22
# 254398 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035 2019-01-28
# 1      2019-01-28 14:15:00       185 Maple St, Portland, OR 97035 2019-01-28
# 2      2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016 2019-01-17
#
#         Month      House_No.            City   Pin_Code   Sales  Hour
# 0           1  944 Walnut St          Boston   MA 02215  700.00    21
# 254397      1  944 Walnut St          Boston   MA 02215  700.00    21
# 254398      1   185 Maple St        Portland   OR 97035   14.95    14
# 1           1   185 Maple St        Portland   OR 97035   14.95    14
# 2           1   538 Adams St   San Francisco   CA 94016   23.98    13

# %%
df.groupby('Hour').count()
# Out:
#       Order_ID  Product  Quantity_Ordered  Price_Each  Order_Date  \
# Hour
# 0         7820     7820              7820        7820        7820
# 1         4700     4700              4700        4700        4700
# 2         2486     2486              2486        2486        2486
# 3         1662     1662              1662        1662        1662
# 4         1708     1708              1708        1708        1708
# 5         2642     2642              2642        2642        2642
# 6         4964     4964              4964        4964        4964
# 7         8022     8022              8022        8022        8022
# 8        12512    12512             12512       12512       12512
# 9        17496    17496             17496       17496       17496
# 10       21888    21888             21888       21888       21888
# 11       24822    24822             24822       24822       24822
# 12       25174    25174             25174       25174       25174
# 13       24258    24258             24258       24258       24258
# 14       21968    21968             21968       21968       21968
# 15       20350    20350             20350       20350       20350
# 16       20768    20768             20768       20768       20768
# 17       21798    21798             21798       21798       21798
# 18       24560    24560             24560       24560       24560
# 19       25810    25810             25810       25810       25810
# 20       24456    24456             24456       24456       24456
# 21       21842    21842             21842       21842       21842
# 22       17644    17644             17644       17644       17644
# 23       12550    12550             12550       12550       12550
#
#       Purchase_Address   Date  Month  House_No.   City  Pin_Code  Sales
# Hour
# 0                 7820   7820   7820       7820   7820      7820   7820
# 1                 4700   4700   4700       4700   4700      4700   4700
# 2                 2486   2486   2486       2486   2486      2486   2486
# 3                 1662   1662   1662       1662   1662      1662   1662
# 4                 1708   1708   1708       1708   1708      1708   1708
# 5                 2642   2642   2642       2642   2642      2642   2642
# 6                 4964   4964   4964       4964   4964      4964   4964
# 7                 8022   8022   8022       8022   8022      8022   8022
# 8                12512  12512  12512      12512  12512     12512  12512
# 9                17496  17496  17496      17496  17496     17496  17496
# 10               21888  21888  21888      21888  21888     21888  21888
# 11               24822  24822  24822      24822  24822     24822  24822
# 12               25174  25174  25174      25174  25174     25174  25174
# 13               24258  24258  24258      24258  24258     24258  24258
# 14               21968  21968  21968      21968  21968     21968  21968
# 15               20350  20350  20350      20350  20350     20350  20350
# 16               20768  20768  20768      20768  20768     20768  20768
# 17               21798  21798  21798      21798  21798     21798  21798
# 18               24560  24560  24560      24560  24560     24560  24560
# 19               25810  25810  25810      25810  25810     25810  25810
# 20               24456  24456  24456      24456  24456     24456  24456
# 21               21842  21842  21842      21842  21842     21842  21842
# 22               17644  17644  17644      17644  17644     17644  17644
# 23               12550  12550  12550      12550  12550     12550  12550

# %%
hours = [hour for hour, df in df.groupby('Hour')]
plt.plot(hours, df.groupby('Hour').count())
plt.grid(True)
plt.xticks(hours)
plt.xlabel('Hours in 24 Hr Format')
plt.ylabel('Orders')
plt.show()

# %%
# 7pm most orders are placed because people like shopping after office or in the evening
# 3am -4 am is least  because most people must be sleeping
# 11am-12 noon is maximum after 7 pm 
# store should come with offer and discount in the night and early morning to encourage shopping

# %% [markdown]
# # Q6 Find out the pair of products that are most sold together. For example, generally, we would expect a person who buys an iPhone 11 to also buy the Apple Airpods together with it. Identify such pairs of products and suggest what promotional offers should the retail company come up with based on your outcome?.

# %%
dfa
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone                 1         700
# 254398    141235    Lightning Charging Cable                 1       14.95
# 2         141236            Wired Headphones                 2       11.99
# 3         141237            27in FHD Monitor                 1      149.99
# 4         141238            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 186846    319667       AA Batteries (4-pack)                 2        3.84
# 242358    319668             Vareebadd Phone                 1         400
# 242359    319669            Wired Headphones                 1       11.99
# 186849    319670  Bose SoundSport Headphones                 1       99.99
# 124526  Order ID                     Product  Quantity Ordered  Price Each
#
#             Order Date                        Purchase Address
# 0       01/22/19 21:25         944 Walnut St, Boston, MA 02215
# 254398  01/28/19 14:15        185 Maple St, Portland, OR 97035
# 2       01/17/19 13:33   538 Adams St, San Francisco, CA 94016
# 3       01/05/19 20:33      738 10th St, Los Angeles, CA 90001
# 4       01/25/19 11:59           387 10th St, Austin, TX 73301
# ...                ...                                     ...
# 186846  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001
# 242358  12/09/19 06:43        273 Wilson St, Seattle, WA 98101
# 242359  12/03/19 10:39          778 River St, Dallas, TX 75001
# 186849  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001
# 124526      Order Date                        Purchase Address
#
# [185687 rows x 6 columns]

# %%
order = dfa[dfa['Order ID'].duplicated(keep = False)] 
order
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 41       141275      USB-C Charging Cable                1      11.95
# 42       141275          Wired Headphones                1      11.99
# 58       141290     AA Batteries (4-pack)                3       3.84
# 254454   141290  Apple Airpods Headphones                1        150
# 254530   141365           Vareebadd Phone                1        400
# ...         ...                       ...              ...        ...
# 242271   319584                    iPhone                1        700
# 242285   319596  Lightning Charging Cable                1      14.95
# 242284   319596                    iPhone                1        700
# 242321   319631  Lightning Charging Cable                1      14.95
# 186809   319631    34in Ultrawide Monitor                1     379.99
#
#             Order Date                        Purchase Address
# 41      01/07/19 16:06         610 Walnut St, Austin, TX 73301
# 42      01/07/19 16:06         610 Walnut St, Austin, TX 73301
# 58      01/02/19 08:25         4 1st St, Los Angeles, CA 90001
# 254454  01/02/19 08:25         4 1st St, Los Angeles, CA 90001
# 254530  01/10/19 11:19  20 Dogwood St, New York City, NY 10001
# ...                ...                                     ...
# 242271  12/11/19 00:30       537 Sunset St, Portland, OR 97035
# 242285  12/01/19 08:44    436 14th St, New York City, NY 10001
# 242284  12/01/19 08:44    436 14th St, New York City, NY 10001
# 242321  12/17/19 22:35       363 Highland St, Austin, TX 73301
# 186809  12/17/19 22:35       363 Highland St, Austin, TX 73301
#
# [14128 rows x 6 columns]

# %%
order['Ordered Together'] = order.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
order = order[['Order ID','Ordered Together']].drop_duplicates()
order.head(10)
# Out:
# <ipython-input-66-68beef9dcce9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['Ordered Together'] = order.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
#        Order ID                                  Ordered Together
# 41       141275             USB-C Charging Cable,Wired Headphones
# 58       141290    AA Batteries (4-pack),Apple Airpods Headphones
# 254530   141365                  Vareebadd Phone,Wired Headphones
# 254550   141384                 Google Phone,USB-C Charging Cable
# 254618   141450           Bose SoundSport Headphones,Google Phone
# 254626   141457                   Apple Airpods Headphones,iPhone
# 254648   141478             Apple Airpods Headphones,Google Phone
# 324      141550  Apple Airpods Headphones,iPhone,Wired Headphones
# 362      141587     USB-C Charging Cable,Apple Airpods Headphones
# 254819   141645         Wired Headphones,Lightning Charging Cable

# %%
from itertools import combinations
from collections import Counter 

count = Counter()

for row in order['Ordered Together']:
    items = row.split(',')
    count.update(Counter(combinations(items,2))) # Most Common Pair of Products Bought Together.

for key, value in count.most_common(10): # Top 10 Products Pair Bought Together.
    print(key,value)
# Out:
# ('Lightning Charging Cable', 'iPhone') 522
# ('USB-C Charging Cable', 'Google Phone') 499
# ('Google Phone', 'USB-C Charging Cable') 498
# ('iPhone', 'Lightning Charging Cable') 489
# ('iPhone', 'Wired Headphones') 238
# ('Wired Headphones', 'iPhone') 224
# ('Google Phone', 'Wired Headphones') 213
# ('Wired Headphones', 'Google Phone') 209
# ('USB-C Charging Cable', 'Vareebadd Phone') 189
# ('iPhone', 'Apple Airpods Headphones') 187

# %%
# As we can see that iphone and light charging cabel is the most sold product as a pair.
# This can be because company doesnot provide charger while selling the phone
# second most sold product is usb c charging cabel and google phone

# %%
product_group = df.groupby('Product')

quantity_ordered = product_group.sum()['Quantity_Ordered']

products = [product for product, detail in product_group]

# %%
plt.figure(figsize = (20,5))
plt.bar(products, quantity_ordered)

plt.xticks(products, rotation = 'vertical')

plt.title('Most Sold Products')

plt.xlabel('Products')

plt.ylabel('Quantity of Products');

# %%
prices = df.groupby('Product').mean()['Price_Each']

fig, ax1 = plt.subplots(figsize = (20,5))

ax2 = ax1.twinx() # Common X Axis

ax1.bar(products, quantity_ordered, color = 'blue')

ax2.plot(products, prices, color = 'red')

ax1.set_xlabel('Product Name')

ax1.set_ylabel('Quantity Ordered', color = 'blue')

ax2.set_ylabel('Price in USD', color = 'red')

ax1.set_xticklabels(products, rotation = 'vertical');
# Out:
# <ipython-input-81-b194315e6832>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products, rotation = 'vertical');

# %%
# as we can see that aa and aaa batteries are most sold because we need it many uses.
# second the charging cabels are most sold because its malfunction more often so we need it regularly
# wired phone and apple airpods are also sold well
# so accessories are most sold 
#in mobile is vareebadd phone may be because its not good 
# lg company dryer and washing machine is least sale 
#so lg company is not doing well across all the city
#Offers:-
#lg company should come with offers to inrease there sales
#iphone should give chariging cables which may increases it sales
#lg can come with promotional offer by giving dryer free along with the washing machine.

# %% [markdown]
# # Conclusion

# %%
# 1. data set are loaded
# 1a  It has  column of order id, quantity,order date addresss,price ,product
# 2  data is prepared for further analysis
# 2a Nan value present in data set are dropped
# 2b  Dublpicate values are deleted
# 2c  Column name are changed for better analysis
# 2d  Pincode ,city name are extracted and  given separate column
# 2e   separate sales column are made for further analysis
# 3 In new data set we donot have any nan values,dublicate values, we have separat column of sales,pincode,city.
# 3b  data types are changed of Order_ID for analysis
# 4 December is the month where more sales are happening may be because of christmas.
# 4b San Fransisco is the city where most sells are happening
# 4c New york city selling more products.
# 5 Most sales occuring at 7 evening may be because people like to shop in the evening.
 # 5.1 After 7pm its between 11am to 12 noon where most sales are happening.
 # 5.2 sales are least in 4 am morning which and decrease after 7pm so stores should offer some discount in night to increase sales at nigh

# 6 iphone and charging cables are most sold product together.
# 6.this is because iphone not giving charging cables along with mobile
# 6. lg items have least sales so company should offer discount.\
# 6. Accesories like headphone,charging cable, aa and aaa batteries are most sold item may be because of its  less durabiltiy.
# 6. There should be promotional offer like lg washing machine should offer lg dryer to increase its sales
# 6 veerband phone should offer discount or  free headphone and charging cabels.
